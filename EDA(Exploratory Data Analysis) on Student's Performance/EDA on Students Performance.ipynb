# %% [markdown]
# # Minor Project

# %% [markdown]
# ## Topic : EDA on Student's Performance
# #### Solution by:- **Anurag Singh**

# %% [markdown]
# ### In this Minor Project, we are given a Student's Performance dataset,<br>we have to perform EDA i.e.(Exploratory Data Analysis) to get a deep insight of the data and to measure the effect of different factors on the student's performance.

# %% [markdown]
# - **Importing the libraries**:-

# %%
import pandas as pd                #for data preprocessing
import numpy as np                 #for working with arrays and its useful functions
import matplotlib.pyplot as plt    #for data visualization
import seaborn as sns              #for data visualization
# %matplotlib inline 
import matplotlib.pyplot as plt

# %% [markdown]
# The libraries have been imported in the notebook.<br>
# The last line(i.e. %matplotlib inline) is used to display the visual images in the notebook itself.

# %% [markdown]
# - **Importing the dataset**:-

# %%
#save the dataset .ipynb file and this file in the same directory
#reading dataset in the notebook

sp = pd.read_csv("StudentsPerformance (1).csv")
sp
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Dataset imported.

# %%
#to display the first 5 rows
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# - **To know the number of students**:-

# %%
#to know the number of rows and columns
sp.shape
# Out:
# (1000, 8)

# %% [markdown]
# Hence, we get to know that there are **1000 students** in total (including both male and female).

# %% [markdown]
# - **To know the columns**:-

# %%
#to get the collumns
sp.columns.to_list()
sp.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# There are **8 columns** in total.

# %%
#to know about the index
sp.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# - **To know about the data type of each column**:-

# %%
#to know about the data types of each column
sp.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# We observe that, the first **5 columns** are of **object(string)** data type whereas the last **3 columns** are of **integer** data type.

# %% [markdown]
# - **To get the summary statistics of the dataset**:-

# %%
#to get the summary statistics
sp.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# - **To know about the brief description of the dataset**:-

# %%
#to get the brief detail about the dataset
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# - **To find if there are any missing(null/nan) values or not**:-

# %%
#to check missing data
sp.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# We observe that, there are **no missing values** in each column, which is great!!!

# %% [markdown]
# - **Visual insight of missing values**:-

# %%
#if the dataset is very large then to visualize the missing values, we will use the following:-
#use seaborn heatmap to see where we are missing data
#as you can see the heatmap is of solid color, and no other color is present, which means no missing values(null)
sns.heatmap(sp.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# Here, we have used a heatmap from seaborn library to visualize the dataset for any missing values, if there were any other colors in the heatmap, that would show that there are some missing values, and the number of missing values depends on the density of the different color in the heatmap.
# <br>
# <br>
# Now I have used this because, it is very helpful to know in cases where **there are missing values**, to know that:-
# - whether we want to replace the missing values with some other values **or**
# - whether we want to completely remove the column if it is not much relevant in analysis.

# %% [markdown]
# - **To find the number of male and female students**:-

# %%
print(sp['gender'].value_counts())

sns.set_style("whitegrid")
sns.countplot(x='gender', data=sp)
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# We observe that, there are **518 female** and **482 male** students in the dataset.
# <br>
# Hence, **female students are more as compared to male students**.

# %% [markdown]
# - **To know the number of students belonging to different caste/race/ethnicity**:-

# %%
print(sp['race/ethnicity'].value_counts())

sns.set_style("whitegrid")
sns.countplot(x='race/ethnicity', data=sp)
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# The numerical figures are above the graph for your reference.<br>
# But we observe that out of 1000 students, **maximum students belong to group C(middle class)** and **minimum students belong to group A(upper class)**.

# %% [markdown]
# - **To know the number of students belonging to different caste/race/ethnicity 'gender wise'**:-

# %%
sns.set_style("whitegrid")
sns.countplot(x='race/ethnicity', hue='gender', data=sp, palette='rainbow')

# %% [markdown]
# We observe that:- <br>
# - among the group **A**(upper class), **males > females** in numbers.<br>
# - among the group **C**(middle class), **males < females** in numbers by large quantity.<br>
# - among the group **E**(lower class), **males = females** almost.

# %% [markdown]
# - **To know the 'education level of the parents' of the students**:-

# %%
print(sp['parental level of education'].value_counts())

sns.set_style("whitegrid")
sns.catplot(x="parental level of education", data=sp, kind="count", aspect=2)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# The numerical figures are above the graph for your reference.<br>
# But we observe that out of 1000 students, **maximum(375) students come from the family where parents are "high school" degree holders** and **minimum(59) students come from the family where parents are "master's degree" holders**.

# %% [markdown]
# - **To know the 'education level of the parents' of the students 'gender wise'**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x="parental level of education", hue='gender', data=sp, kind="count", aspect=2, palette='rainbow')

# %% [markdown]
# We observe that, out of 1000 students, **whose parents are having "high school degree"(parents of most number of students), males > females in number** and **those whose parents are having "master's degree"(parents of least number of students), females > males**.

# %% [markdown]
# - **To know the number of students having lunch at 'standard rate' or 'reduced rate/free'**:-

# %%
print(sp['lunch'].value_counts())

sns.set_style("whitegrid")
sns.countplot(x='lunch', data=sp)
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %% [markdown]
# The numerical figures are above the graph for your reference.<br>
# But we observe that out of 1000 students, **645 students are having lunch at "standard rate"** and **355 students are having lunch at "free/reduced rate"**.

# %% [markdown]
# - **To know the number of students having lunch at 'standard rate' or 'reduced rate/free' gender wise**:-

# %%
sns.set_style("whitegrid")
sns.countplot(x='lunch', hue='gender', data=sp, palette='rainbow')

# %% [markdown]
# We observe that out of 1000 students, in both the categories of lunch, **females > males** but not by large numbers.

# %% [markdown]
# - **To know the number of students who have done any course for test preparation or not**:-

# %%
print(sp['test preparation course'].value_counts())

sns.set_style("whitegrid")
sns.countplot(x='test preparation course', data=sp)
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# The numerical figures are above the graph for your reference.<br>
# But we observe that out of 1000 students, **642 students have not done any course** and **358 students have completed a course**.

# %% [markdown]
# - **To know the number of students who have done any course for test preparation or not 'gender wise'**:-

# %%
sns.set_style("whitegrid")
sns.countplot(x='test preparation course', hue='gender', data=sp, palette='rainbow')

# %% [markdown]
# We observe that out of 1000 students, among the ones **who have not done any course, females > males**, on the other hand among the ones **who have completed the course, females > males but not in large numbers**.

# %% [markdown]
# - **Now we will calculate the 'Total Score' and 'Average Score' of all the students**:-

# %%
sp['total'] = sp['math score'] + sp['reading score'] + sp['writing score']

# %%
sp['average'] = sp['total'] / 3

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %% [markdown]
# The **total** and **average** columns have been added to the dataframe successfully.<br>
# This will help us to interpret data more deeply.

# %% [markdown]
# **Numerical data analysis**:-

# %%
sns.set_style("whitegrid")
sns.pairplot(sp, kind='scatter')

# %% [markdown]
# ### Maths Score Analysis

# %% [markdown]
# - **To analyze 'math score' among 1000 students**:-

# %%
print(sp['math score'].mean())

sns.set_style("whitegrid")
sns.distplot(sp['math score'], color='red', kde=True)
# Out:
# 66.089

# %% [markdown]
# We observe that, most students have scored **66 marks in maths** on an average.

# %% [markdown]
# - **To analyze 'math score' among 1000 students gender wise**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='gender', y='math score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, most students have scored **66 marks in maths** on an average and among those **males > females**.

# %% [markdown]
# - **To analyze 'math score' among 1000 students on the basis of race/ethnicity/caste**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='race/ethnicity', y='math score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among maths score, **group E(lower class) students have scored most** whereas **group A(upper class) students have scored least**.

# %% [markdown]
# - **To analyze 'math score' among 1000 students on the basis of parental level of education**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='parental level of education', y='math score', data=sp, kind="bar", palette='dark', aspect=2)

# %% [markdown]
# We observe that, among maths score, **students whose parents are "master's degree" holder, have scored the most followed by "bachelor's degree"** whereas **students whose parents are "high school" qualified, have scored the least**.

# %% [markdown]
# - **To analyze 'math score' among 1000 students on the basis of type of lunch**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='lunch', y='math score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among maths score, **students who consume lunch at a standard rate, have scored higher** whereas **students who consume lunch at reduced rates/for free, have scored low**.

# %% [markdown]
# - **To analyze 'math score' among 1000 students on the basis of test preparation course**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='test preparation course', y='math score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among maths score, **students who have completed test preparation course, have scored higher** whereas **students who have not done any course, have scored low**.

# %% [markdown]
# ### Reading Score Analysis

# %% [markdown]
# - **To analyze 'reading score' among 1000 students**:-

# %%
print(sp['reading score'].mean())

sns.set_style("whitegrid")
sns.distplot(sp['reading score'], color='orange')
# Out:
# 69.169

# %% [markdown]
# We observe that, most students have scored **69 marks in reading** on an average, which is greater than maths.

# %% [markdown]
# - **To analyze 'reading score' among 1000 students gender wise**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='gender', y='reading score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, most students have scored **69 marks in reading** on an average and among those **males < females**.

# %% [markdown]
# - **To analyze 'reading score' among 1000 students on the basis of race/ethnicity/caste**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='race/ethnicity', y='reading score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among reading score, **group E(lower class) students have scored most** whereas **group A(upper class) students have scored least**, which is similar to maths score but here **group C(middle class)** students have scored well which shows they are good in reading than maths.

# %% [markdown]
# - **To analyze 'reading score' among 1000 students on the basis of parental level of education**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='parental level of education', y='reading score', data=sp, kind="bar", palette='dark', aspect=2)

# %% [markdown]
# We observe that, among reading score, **students whose parents are "master's degree" holder, have scored the most followed by "bachelor's degree"** whereas **students whose parents are "high school" qualified, have scored the least**, which is similar to maths score analysis, but here one good thing is that most of them are crossing 70 scoreline, which shows that they are good in reading than in maths.

# %% [markdown]
# - **To analyze 'reading score' among 1000 students on the basis of type of lunch**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='lunch', y='reading score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among reading score, **students who consume lunch at a standard rate, have scored higher** whereas **students who consume lunch at reduced rates/for free, have scored low**, but here all of them are scoring better than maths analysis, crossing 70 scoreline and 60 scoreline.

# %% [markdown]
# - **To analyze 'reading score' among 1000 students on the basis of test preparation course**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='test preparation course', y='reading score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among reading score, **students who have completed test preparation course, have scored higher** whereas **students who have not done any course, have scored low**, but here, they scored more than maths analysis.

# %% [markdown]
# ### Writing Score Analysis

# %% [markdown]
# - **To analyze 'writing score' among 1000 students**:-

# %%
print(sp['writing score'].mean())

sns.set_style("whitegrid")
sns.distplot(sp['writing score'], color='green')
# Out:
# 68.054

# %% [markdown]
# We observe that, most students have scored **68 marks in writing** on an average.

# %% [markdown]
# - **To analyze 'writing score' among 1000 students gender wise**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='gender', y='writing score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, most students have scored **68 marks in writing** on an average and among those **males < females**. This is same as reading analysis.

# %% [markdown]
# - **To analyze 'writing score' among 1000 students on the basis of race/ethnicity/caste**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='race/ethnicity', y='writing score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among writing score, **group E and group D(lower class) students have scored most** whereas **group A(upper class) students have scored least**, which is similar to maths score but here also **group C(middle class)** students have scored well which shows they are good in wring than maths and on the same level as reading in writing.

# %% [markdown]
# - **To analyze 'writing score' among 1000 students on the basis of parental level of education**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='parental level of education', y='writing score', data=sp, kind="bar", palette='dark', aspect=2)

# %% [markdown]
# We observe that, among writing score, **students whose parents are "master's degree" holder, have scored the most followed by "bachelor's degree"** whereas **students whose parents are "high school" qualified, have scored the least**, which is similar to maths score and reading score analysis, but again one good thing is that most of them are crossing 70 scoreline, which shows that they are good in reading than in maths.

# %% [markdown]
# - **To analyze 'writing score' among 1000 students on the basis of type of lunch**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='lunch', y='writing score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among writing score, **students who consume lunch at a standard rate, have scored higher** whereas **students who consume lunch at reduced rates/for free, have scored low**, but here, all of them are scoring better than maths analysis and similar to reading analysis, crossing 70 scoreline and 60 scoreline.

# %% [markdown]
# - **To analyze 'writing score' among 1000 students on the basis of test preparation course**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='test preparation course', y='writing score', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, among writing score, **students who have completed test preparation course, have scored higher** whereas **students who have not done any course, have scored low**, but here, they scored more than maths analysis and almost similar to reading analysis.

# %% [markdown]
# ### Average Score(Math Score + Reading Score + Writing Score) Analysis

# %%
print(sp['average'].mean())

sns.set_style("whitegrid")
sns.distplot(sp['average'], color='black')
# Out:
# 67.77066666666664

# %% [markdown]
# We observe that, the **average marks of the students is 67.7 in all the subjects**.

# %% [markdown]
# - **To analyze 'average' among 1000 students gender wise**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='gender', y='average', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, on an average **males < females** scoring wise in all the subjects combined, but not by a huge difference.<br>
# They all are scoring **above average** i.e. **between 60 and 70 marks**.

# %% [markdown]
# - **To analyze 'average' among 1000 students on the basis of race/ethnicity/caste**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='race/ethnicity', y='average', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, overall, **group E and group D(lower class) students have scored the most** whereas **group A(upper class) students have scored the least**, which shows how hardworking lower class students are as compared to upper class. Also **group C(middle class)** students have scored in between the other two class which shows they are performing average which is good.

# %% [markdown]
# - **To analyze 'average' among 1000 students on the basis of parental level of education**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='parental level of education', y='average', data=sp, kind="bar", palette='dark', aspect=2)

# %% [markdown]
# We observe that, overall, **students whose parents are "master's degree" holder, have scored the most followed by "bachelor's degree"** whereas **students whose parents are "high school" qualified, have scored the least**, but all of them are performing above average.

# %% [markdown]
# - **To analyze 'average' among 1000 students on the basis of type of lunch**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='lunch', y='average', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, overall, **students who consume lunch at a standard rate, have scored higher** whereas **students who consume lunch at reduced rates/for free, have scored low**, hence, crossing 70 scoreline and 60 scoreline which proves they are scoring not very bad and also not very good but above average.

# %% [markdown]
# - **To analyze 'average' among 1000 students on the basis of test preparation course**:-

# %%
sns.set_style("whitegrid")
sns.catplot(x='test preparation course', y='average', data=sp, kind="bar", palette='dark')

# %% [markdown]
# We observe that, overall, **students who have completed test preparation course, have scored higher** whereas **students who have not done any course, have scored low** which shows **above average performance by students who have'nt completed any course** but **good performance(crossing 70 scoreline) by students who have completed course**.

# %% [markdown]
# ### Miscellaneous Analysis

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average
# 0  72.666667
# 1  82.333333
# 2  92.666667
# 3  49.333333
# 4  76.333333

# %% [markdown]
# - **Here I am analyzing the dataset for those students who have "not completed any test preparation course" and are "passing" the exams**:-

# %%
m1 = sp['test preparation course']=='none'
m2 = sp['average'] >= 40
sp1 = sp.loc[m1 & m2, ['gender', 'test preparation course', 'average']]

print(sp1['test preparation course'].value_counts())
print()
print(sp1['gender'].value_counts())

sns.set_style("whitegrid")
sns.catplot(x='test preparation course', y='average', hue='gender', data=sp1, kind="point", palette='pastel')    
#point plot gives more precise analysis, thats why I used this to get accurate average score
# Out:
# none    615
# Name: test preparation course, dtype: int64
#
# female    320
# male      295
# Name: gender, dtype: int64

# %% [markdown]
# We observe that, there are **615 students(i.e. more than 50% of the total students) who have not completed any test preparation course and are still passing the exams**. <br>
# Among these, **females(320 students) > males(295 students)**.<br>
# Also, on an average, **females are scoring 68.5 %** as compared to **males who are scoring 64.3 %**.

# %% [markdown]
# - **Here I am analyzing the dataset for those students who have "completed any test preparation course" and are "passing" the exams**:-

# %%
m3 = sp['test preparation course']=='completed'
m4 = sp['average'] >= 40
sp2 = sp.loc[m3 & m4, ['gender', 'test preparation course', 'average']]

print(sp2['test preparation course'].value_counts())
print()
print(sp2['gender'].value_counts())

sns.catplot(x='test preparation course', y='average', hue='gender', data=sp2, kind="point", palette='pastel')
#point plot gives more precise analysis, thats why I used this to get accurate average score
# Out:
# completed    355
# Name: test preparation course, dtype: int64
#
# female    182
# male      173
# Name: gender, dtype: int64

# %% [markdown]
# We observe that, there are **355 students(i.e. less than 50% of the total students) who have completed any test preparation course and are passing the exams**. <br>
# Among these, **females(182 students) > males(173 students)**.<br>
# Also, **females are scoring 74.9 %** as compared to **males who are scoring 70.95 %**.

# %% [markdown]
# **So, the students who have completed the 'test preparation course' are scoring well than the ones who "have not" taken any 'test preparation course', but also, they(who completed test preparation course) are lesser in number**.

# %% [markdown]
# - **Adding 4 more columns to the dataframe**:-

# %%
sp['math_pass/fail'] = np.where(sp['math score'] < 40, 'F', 'P')

# %%
sp['reading_pass/fail'] = np.where(sp['reading score'] < 40, 'F', 'P')

# %%
sp['writing_pass/fail'] = np.where(sp['writing score'] < 40, 'F', 'P')

# %%
sp['overall_pass'] = np.where((sp['total']/300*100) < 40, 'F', 'P')

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average math_pass/fail reading_pass/fail writing_pass/fail overall_pass
# ...

# %% [markdown]
# - **Overall number of students who are passing or failing**:-

# %%
print(sp['overall_pass'].value_counts())

sp['overall_pass'].value_counts().plot(kind='barh', color='grey')
# Out:
# P    970
# F     30
# Name: overall_pass, dtype: int64

# %% [markdown]
# **All in all, whether a student has taken any 'test preparation course' or not, the total number of students who "passed is 970" and the number of students who "failed is 30", which is good as overall, 97 % students passed even though they did'nt performed excellently but decent enough. Main thing is that not many students failed**.

# %% [markdown]
# ### Number of students passing in respective subjects:-

# %% [markdown]
# - **Maths**:-

# %%
print(sp['math_pass/fail'].value_counts())

sp['math_pass/fail'].value_counts().plot(kind='barh', color='red')
# Out:
# P    960
# F     40
# Name: math_pass/fail, dtype: int64

# %% [markdown]
# We observe that, **960 students passed in maths** and **40 failed**.

# %% [markdown]
# - **Reading**:-

# %%
print(sp['reading_pass/fail'].value_counts())

sp['reading_pass/fail'].value_counts().plot(kind='barh', color='yellow')
# Out:
# P    974
# F     26
# Name: reading_pass/fail, dtype: int64

# %% [markdown]
# We observe that, **974 students passed in reading** and **26 failed**.

# %% [markdown]
# - **Writing**:-

# %%
print(sp['writing_pass/fail'].value_counts())

sp['writing_pass/fail'].value_counts().plot(kind='barh', color='green')
# Out:
# P    968
# F     32
# Name: writing_pass/fail, dtype: int64

# %% [markdown]
# We observe that, **968 students passed in writing** and **32 failed**.

# %% [markdown]
# **Students performed best in Reading > Writing > Maths**.

# %%
sp.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average math_pass/fail reading_pass/fail writing_pass/fail overall_pass
# ...

# %% [markdown]
# - **Gender wise analysis who "Passed"**:-

# %%
m5 = sp['gender']=='male'
m6 = sp['overall_pass']=='P'
sp3 = sp.loc[m5 & m6, ['gender', 'overall_pass']]

sp3.loc[m5 & m6, ['gender', 'overall_pass']].shape
# Out:
# (468, 2)

# %%
m1 = sp['gender']=='female'
m2 = sp['overall_pass']=='P'

sp.loc[m1 & m2, ['gender', 'overall_pass']].shape
# Out:
# (502, 2)

# %% [markdown]
# We observe that, among the students who **passed, females(502 students) > males(468 students)** out of 970.

# %% [markdown]
# - **Gender wise analysis who "Failed"**:-

# %%
m1 = sp['gender']=='male'
m2 = sp['overall_pass']=='F'
sp.loc[m1 & m2, ['gender', 'overall_pass']].shape
# Out:
# (14, 2)

# %%
m1 = sp['gender']=='female'
m2 = sp['overall_pass']=='F'
sp.loc[m1 & m2, ['gender', 'overall_pass']].shape
# Out:
# (16, 2)

# %% [markdown]
# We observe that, among the students who **failed, females(16 students) > males(14 students)** out of 30.

# %% [markdown]
# **Overall we can say that females performed better than males**.

# %% [markdown]
# - **Students analysis who passed or failed in 'maths' on the basis of their "parent's level of education"**:-

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='parental level of education', data=sp, hue='math_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=65)

# %% [markdown]
# We observe that, in **maths(940 passing and 40 failing)**, the parents who have a **'high school' degree, their childrens are maximum in numbers who are passing**, followed by the parents with **'some college' degree** and **'associates degree'** whereas the parents who are **'masters degree holder', their children are least in number who are passing**.<br>
# On the other hand, in **maths** only, the parents who are **'masters degree holder', their children are not failing**, whereas the parents having **'high school'** degree, their children are **maximum in number who are failing**.

# %% [markdown]
# - **Students analysis who passed or failed in 'reading' on the basis of their "parent's level of education"**:-

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='parental level of education', data=sp, hue='reading_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=65)

# %% [markdown]
# We observe that, in **reading(974 passing and 26 failing)**, the parents who have a **'high school' degree, their childrens are maximum in numbers who are passing**, followed by the parents with **'some college' degree** and **'associates degree'** whereas the parents who are **'masters degree holder', their children are least in number who are passing**.<br>
# On the other hand, in **reading** only, the parents who are **'masters degree holder', their children are not failing**, whereas the parents having **'high school'** degree, their children are **maximum in number who are failing**.

# %% [markdown]
# - **Students analysis who passed or failed in 'writing' on the basis of their "parent's level of education"**:-

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='parental level of education', data=sp, hue='writing_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=65)

# %% [markdown]
# We observe that, in **writing(968 passing and 32 failing)**, the parents who have a **'high school' degree, their childrens are maximum in numbers who are passing**, followed by the parents with **'some college' degree** and **'associates degree'** whereas the parents who are **'masters degree holder', their children are least in number who are passing**.<br>
# On the other hand, in **writing** only, the parents who are **'masters degree holder', their children are not failing**, whereas the parents having **'high school'** degree, their children are **maximum in number who are failing**.

# %% [markdown]
# - **Students Performance analysis who passed or failed on the basis of their "test preparation course"**:-

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='test preparation course', data=sp, hue='math_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=0)

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='test preparation course', data=sp, hue='reading_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=0)

# %%
sns.set_style("whitegrid")
p = sns.countplot(x='test preparation course', data=sp, hue='writing_pass/fail', palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=0)

# %% [markdown]
# From the above three graph visuals, we can say that the **students who did not completed any test preparation course are very hardworking as they are maximum in numbers who passed in each subject**, but we can also see that **among the students who completed the test preparation course, the number of students who failed are 0 in reading and writing and almost negligible in maths**, which is not the thing with those who did not completed any test preparation course.

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#      average math_pass/fail reading_pass/fail writing_pass/fail overall_pass
# ...

# %% [markdown]
# - **Here I tried to give somewhat more emphasis on the type of 'lunch' that student consumes**:-

# %%
sp.loc[(sp['lunch']=='standard') & (sp['average']>=90), 'average'].shape
# Out:
# (48,)

# %% [markdown]
# **Out of 1000 students, those who are exceptional performers(i.e. >= 90 % overall), and their lunch cost is "standard", they are only 48 in total**.

# %%
m1 = sp['lunch']=='standard'
m2 = sp['average']>=90

sp.loc[m1 & m2, ['lunch', 'average']].plot(kind='hist', bins=10, color='orange')

# %% [markdown]
# **Among those students also, maximum(10 students) are between 91-92 % and there are very few who reached near 100 %(like around 6 only)**. Wow.....!!!!

# %%
sp.loc[(sp['lunch']=='free/reduced') & (sp['average']>=90), 'average'].shape
# Out:
# (4,)

# %% [markdown]
# **Out of 1000 students, those who are exceptional performers(i.e. >= 90 % overall), and their lunch cost is "reduced/free", they are only 4 in total**.

# %%
m1 = sp['lunch']=='free/reduced'
m2 = sp['average']>=90

sp.loc[m1 & m2, ['lunch', 'average']].plot(kind='hist', bins=10)

# %% [markdown]
# **Among those students also, maximum(3 students) have crossed 97 % barrier and there is only 1 student who scored beyond 93 %**.<br> Exceptional.....!!!!

# %% [markdown]
# **Basically I believe that, those students who performed exceptionally well(i.e. >= 90 %), among those also the Scholarship Holders are only 4 in numbers(as there lunch is provided to them at reduced cost/free) on the basis of analysis**.
